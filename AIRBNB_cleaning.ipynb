# %%
pip install pymongo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pymongo

# %%
client = pymongo.MongoClient("mongodb+srv://morlensamuels:12345@cluster.hdxmqrv.mongodb.net/?retryWrites=true&w=majority")
db = client.sample_airbnb
collection = db.listingsAndReviews

# %%
data = []
for i in collection.find():
  data.append(i)

# %%
#data

# %%
pd.set_option('display.max_columns', 500)

# %%
airbnb = pd.DataFrame(data)
#airbnb

# %%
airbnb.to_csv('airbnb.csv', index=False)

# %%
"""_id: An identifier for the listing.
listing_url: The URL or link to the listing on a website or platform.
name: The name or title of the listing.
summary: A brief summary or description of the property.
space: Information about the space or interior of the property.
description: A more detailed description of the property.
neighborhood_overview: Information about the neighborhood or area where the property is located.
notes: Any additional notes or comments about the listing.
transit: Details about public transportation options near the property.
access: Information about guest access to the property.
interaction: Details about how the host interacts with guests.
house_rules: Any rules or guidelines for guests staying at the property.
property_type: The type of property (e.g., apartment, house, villa).
room_type: The type of room or accommodation (e.g., private room, entire place).
bed_type: The type of bed(s) available (e.g., queen, king, sofa bed).
minimum_nights: The minimum number of nights required for booking.
maximum_nights: The maximum number of nights a guest can stay.
cancellation_policy: The policy governing cancellations for the booking.
last_scraped: The date when the listing data was last collected.
calendar_last_scraped: The date when the availability calendar data was last collected.
first_review: The date of the first guest review.
last_review: The date of the most recent guest review.
accommodates: The maximum number of guests the property can accommodate.
bedrooms: The number of bedrooms in the property.
beds: The number of beds in the property.
number_of_reviews: The total number of guest reviews.
bathrooms: The number of bathrooms in the property.
amenities: A list of amenities or features provided in the property.
price: The nightly price for renting the property.
security_deposit: The amount of security deposit required.
cleaning_fee: The fee for cleaning services.
extra_people: The cost for additional guests beyond the base number.
guests_included: The number of guests included in the base price.
images: Information about images or photos of the property.
host: Information about the host of the property.
address: The address or location of the property.
availability: Information about the availability of the property.
review_scores: Scores related to guest reviews.
reviews: Additional information or statistics about reviews.
weekly_price: The price for a weekly stay.
monthly_price: The price for a monthly stay.
reviews_per_month: The average number of reviews received per month."""

# %%
airbnb_1 = pd.read_csv('airbnb.csv')
#airbnb_1

# %%
airbnb_1.drop(columns=['address'], inplace=True)
airbnb_1.drop(columns=['host'], inplace=True)
airbnb_1.drop(columns=['availability'], inplace=True)
airbnb_1.drop(columns=['review_scores'], inplace=True)
airbnb_1.drop(columns=['amenities'], inplace=True)
airbnb_1.drop(columns=['images'], inplace=True)
airbnb_1.drop(columns=['reviews'], inplace=True)
airbnb_1.drop(columns=['listing_url'], inplace=True)
airbnb_1.drop(columns=['summary'], inplace=True)
airbnb_1.drop(columns=['first_review'], inplace=True)
airbnb_1.drop(columns=['last_review'], inplace=True)
airbnb_1.drop(columns=['interaction'], inplace=True)
airbnb_1.drop(columns=['cleaning_fee'], inplace=True)
airbnb_1.drop(columns=['space'], inplace=True)
airbnb_1.drop(columns=['description'], inplace=True)
airbnb_1.drop(columns=['neighborhood_overview'], inplace=True)
airbnb_1.drop(columns=['notes'], inplace=True)
airbnb_1.drop(columns=['transit'], inplace=True)
airbnb_1.drop(columns=['house_rules'], inplace=True)
airbnb_1.drop(columns=['access'], inplace=True)
airbnb_1.drop(columns=['last_scraped'], inplace=True)
airbnb_1.drop(columns=['calendar_last_scraped'], inplace=True)
airbnb_1.drop(columns=['security_deposit'], inplace=True)

# %%
missing_values = airbnb_1.isnull().sum()
#print("Missing Values:")
print(missing_values)
# Out:
# _id                       0
# name                      8
# property_type             0
# room_type                 0
# bed_type                  0
# minimum_nights            0
# maximum_nights            0
# cancellation_policy       0
# accommodates              0
# bedrooms                  5
# beds                     13
# number_of_reviews         0
# bathrooms                10
# price                     0
# extra_people              0
# guests_included           0
# weekly_price           4841
# monthly_price          4899
# reviews_per_month      5461
# dtype: int64

# %%
airbnb_1['name'].fillna(airbnb_1['name'].mode()[0], inplace=True)

# %%
#airbnb_1['space'].fillna(airbnb_1['space'].mode()[0], inplace=True)

# %%
#airbnb_1['description'].fillna(airbnb_1['description'].mode()[0], inplace=True)

# %%
#airbnb_1['neighborhood_overview'].fillna(airbnb_1['neighborhood_overview'].mode()[0], inplace=True)

# %%
#airbnb_1['notes'].fillna(airbnb_1['notes'].mode()[0], inplace=True)

# %%
#airbnb_1['transit'].fillna(airbnb_1['transit'].mode()[0], inplace=True)

# %%
#airbnb_1['access'].fillna(airbnb_1['access'].mode()[0], inplace=True)

# %%
#airbnb_1['house_rules'].fillna(airbnb_1['house_rules'].mode()[0], inplace=True)

# %%
airbnb_1['bedrooms'].fillna(airbnb_1['bedrooms'].mean(), inplace=True)

# %%
airbnb_1['beds'].fillna(airbnb_1['beds'].mean(), inplace=True)

# %%
airbnb_1['bathrooms'].fillna(airbnb_1['bathrooms'].mean(), inplace=True)

# %%
#airbnb_1['security_deposit'].fillna(airbnb_1['security_deposit'].mean(), inplace=True)

# %%
airbnb_1['weekly_price'].fillna(airbnb_1['weekly_price'].mean(), inplace=True)

# %%
airbnb_1['monthly_price'].fillna(airbnb_1['monthly_price'].mean(), inplace=True)

# %%
airbnb_1['reviews_per_month'].fillna(airbnb_1['reviews_per_month'].mean(), inplace=True)

# %%
n = pd.DataFrame(airbnb['name'])

# %%
null_name_rows = airbnb[airbnb['name'].isnull()]

# Display the rows with null 'name'
print(null_name_rows)
# Out:
# Empty DataFrame
# Columns: [_id, listing_url, name, summary, space, description, neighborhood_overview, notes, transit, access, interaction, house_rules, property_type, room_type, bed_type, minimum_nights, maximum_nights, cancellation_policy, last_scraped, calendar_last_scraped, first_review, last_review, accommodates, bedrooms, beds, number_of_reviews, bathrooms, amenities, price, security_deposit, cleaning_fee, extra_people, guests_included, images, host, address, availability, review_scores, reviews, weekly_price, monthly_price, reviews_per_month]
# Index: []

# %%
#airbnb.iloc[67] 
airbnb[airbnb['_id'] == 10359729]
# Out:
#          _id                            listing_url name  \
# 67  10359729  https://www.airbnb.com/rooms/10359729  NaN
#
#                                               summary space  \
# 67  We have 2 cozy rooms available from january 12...   NaN
#
#                                           description neighborhood_overview  \
# 67  We have 2 cozy rooms available from january 12...                   NaN
#
#    notes transit access interaction house_rules property_type     room_type  \
# 67   NaN     NaN    NaN         NaN         NaN     Apartment  Private room
#
#     bed_type  minimum_nights  maximum_nights cancellation_policy  \
# 67  Real Bed               1            1125            flexible
#
#            last_scraped calendar_last_scraped first_review last_review  \
# 67  2019-02-18 05:00:00   2019-02-18 05:00:00          NaN         NaN
#
#     accommodates  bedrooms  beds  number_of_reviews  bathrooms  \
# 67             4       1.0   2.0                  0        1.0
#
# ...

# %%
# Imputation: Fill missing 'bathrooms' values with the mean
#df['bathrooms'].fillna(df['bathrooms'].mean(), inplace=True)

# %%
airbnb_1
# Out:
#            _id                                              name  \
# 0     10006546                           Ribeira Charming Duplex
# 1     10038496                      Copacabana Apartment Posto 6
# 2     10069642                Ótimo Apto proximo Parque Olimpico
# 3      1003530               New York City - Upper West Side Apt
# 4     10009999                      Horto flat with small garden
# ...        ...                                               ...
# 5550   9597872  Cosy beach style apartment in the heart of Manly
# 5551   9614181                Excellent studio Copacabana  wi-fi
# 5552   9796437                    Bright, Spacious, Sunlit 2 bed
# 5553   9917859                  StayIN Oporto Música - Apartment
# 5554   9990304    March Madness Special! Aina Nalu Platinum D107
#
#      property_type        room_type  bed_type  minimum_nights  maximum_nights  \
# 0            House  Entire home/apt  Real Bed               2              30
# ...

# %%
airbnb_1.to_csv('airbnb_main.csv', index=False)

# %%
a = pd.DataFrame(airbnb['address'])
a
# Out:
#                                                 address
# 0     {'street': 'Porto, Porto, Portugal', 'suburb':...
# 1     {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
# 2     {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
# 3     {'street': 'New York, NY, United States', 'sub...
# 4     {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
# ...                                                 ...
# 5550  {'street': 'Manly, NSW, Australia', 'suburb': ...
# 5551  {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
# 5552  {'street': 'Bondi, NSW, Australia', 'suburb': ...
# 5553  {'street': 'Porto, Porto, Portugal', 'suburb':...
# 5554  {'street': 'Lahaina, HI, United States', 'subu...
#
# [5555 rows x 1 columns]

# %%
a.to_csv('address_duplicate.csv', index=False)

# %%
address = pd.read_csv('address_duplicate.csv')
address
# Out:
#                                                 address
# 0     {'street': 'Porto, Porto, Portugal', 'suburb':...
# 1     {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
# 2     {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
# 3     {'street': 'New York, NY, United States', 'sub...
# 4     {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
# ...                                                 ...
# 5550  {'street': 'Manly, NSW, Australia', 'suburb': ...
# 5551  {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
# 5552  {'street': 'Bondi, NSW, Australia', 'suburb': ...
# 5553  {'street': 'Porto, Porto, Portugal', 'suburb':...
# 5554  {'street': 'Lahaina, HI, United States', 'subu...
#
# [5555 rows x 1 columns]

# %%
airbnb.address[1].keys()
# Out:
# dict_keys(['street', 'suburb', 'government_area', 'market', 'country', 'country_code', 'location'])

# %%
address = pd.DataFrame(a)


address['street'] = address['address'].apply(lambda x: x['street'])
address['suburb'] = address['address'].apply(lambda x: x['suburb'])
address['government_area'] = address['address'].apply(lambda x: x['government_area'])
address['market'] = address['address'].apply(lambda x: x['market'])
address['country'] = address['address'].apply(lambda x: x['country'])
address['country_code'] = address['address'].apply(lambda x: x['country_code'])
address['type'] = address['address'].apply(lambda x: x['location']['type'])
#address['coordinates'] = address['address'].apply(lambda x: x['location']['coordinates'])
address['Latitude'] = address['address'].apply(lambda x: x['location']['coordinates'][1])
address['Longitude'] = address['address'].apply(lambda x: x['location']['coordinates'][0])
address['is_location_exact'] = address['address'].apply(lambda x: x['location']['is_location_exact'])

# Drop the original 'address' column if not needed
address.drop(columns=['address'], inplace=True)

# Display the updated DataFrame
#print(address)

# %%
print(address['street'].value_counts())
# Out:
# street
# Montréal, Québec, Canada                  492
# Barcelona, Catalunya, Spain               427
# Porto, Porto, Portugal                    351
# Rio de Janeiro, Rio de Janeiro, Brazil    326
# New York, NY, United States               284
#                                          ...
# Roseville, NSW, Australia                   1
# Watsons Bay, NSW, Australia                 1
# İstanbul, Kağıthane, Turkey                 1
# Soho, Hong Kong Island, Hong Kong           1
# Waimanalo Beach, HI, United States          1
# Name: count, Length: 677, dtype: int64

# %%
print(address['suburb'].value_counts())
# Out:
# suburb
#                     887
# Copacabana          154
# Manhattan           148
# Eixample            140
# Brooklyn            129
#                    ...
# Borough Park          1
# Throgs Neck           1
# Ridgewood             1
# Nuuanu/Punchbowl      1
# Gowanus               1
# Name: count, Length: 410, dtype: int64

# %%
len(address['suburb'][0])
# Out:
# 0

# %%
#address[address['suburb']=='']

# %%
address.duplicated().sum()
# Out:
# 0

# %%
address = pd.DataFrame(address)
#address

# %%
address.to_csv('address_duplicate.csv', index=False)

# %%
address = pd.read_csv('address_duplicate.csv')
address
# Out:
#                                       street                    suburb  \
# 0                     Porto, Porto, Portugal                       NaN
# 1     Rio de Janeiro, Rio de Janeiro, Brazil                Copacabana
# 2     Rio de Janeiro, Rio de Janeiro, Brazil  Recreio dos Bandeirantes
# 3                New York, NY, United States                 Manhattan
# 4     Rio de Janeiro, Rio de Janeiro, Brazil           Jardim Botânico
# ...                                      ...                       ...
# 5550                   Manly, NSW, Australia                     Manly
# 5551  Rio de Janeiro, Rio de Janeiro, Brazil                       NaN
# 5552                   Bondi, NSW, Australia                  Tamarama
# 5553                  Porto, Porto, Portugal                       NaN
# 5554              Lahaina, HI, United States                      Maui
#
#                                         government_area          market  \
# ...

# %%
#address['street']

# %%
df = pd.read_csv('address_duplicate.csv')

# Split the 'street' column by comma and select the first part
#df['street'] = df['street'].str.split(',').str[0]
#df['government_area'] = df['government_area'].str.split(',').str[0]
#df = pd.DataFrame(data)

# Custom function to fill NaN values in 'suburb' using 'market'
def fill_suburb_with_market(row):
    if pd.isna(row['suburb']):
        return row['market']
    else:
        return row['suburb']

# Apply the custom function to fill NaN values in 'suburb' column
df['suburb'] = df.apply(fill_suburb_with_market, axis=1)

# Display the DataFrame with NaN values in 'suburb' filled using 'market'
#print(df)

# %%
df.loc[629, 'suburb'] = "Copacabana"

# %%
missing_values = df.isnull().sum()
#print("Missing Values:")
print(missing_values)
# Out:
# street               0
# suburb               0
# government_area      0
# market               0
# country              0
# country_code         0
# type                 0
# Latitude             0
# Longitude            0
# is_location_exact    0
# dtype: int64

# %%
#missing_values = df[df['suburb'].isna()]

#Display the row(s) with missing value(s) in the 'suburb' column
#print(missing_values)
#df.iloc[629]

# %%
#missing_values = df[df['market'].isna()]

#Display the row(s) with missing value(s) in the 'suburb' column
#print(missing_values)
#df.iloc[629]

# %%
df.loc[579, 'market'] = "Québec"
df.loc[629, 'market'] = "Copacabana"
df.loc[661, 'market'] = " Waverly"
df.loc[703, 'market'] = "Manhattan"
df.loc[776, 'market'] = "Sants-Montjuïc"
df.loc[787, 'market'] = "Kauaʻi"

# %%
df['street'] = df['street'].str.split(',').str[0]

# %%
df['government_area'] = df['government_area'].str.split(',').str[0]

# %%
df
# Out:
#               street                    suburb           government_area  \
# 0              Porto                     Porto                 Cedofeita
# 1     Rio de Janeiro                Copacabana                Copacabana
# 2     Rio de Janeiro  Recreio dos Bandeirantes  Recreio dos Bandeirantes
# 3           New York                 Manhattan           Upper West Side
# 4     Rio de Janeiro           Jardim Botânico           Jardim Botânico
# ...              ...                       ...                       ...
# 5550           Manly                     Manly                     Manly
# 5551  Rio de Janeiro            Rio De Janeiro                Copacabana
# 5552           Bondi                  Tamarama                  Waverley
# 5553           Porto                     Porto                 Cedofeita
# 5554         Lahaina                      Maui                   Lahaina
#
#               market        country country_code   type   Latitude  \
# ...

# %%
df.to_csv('address_main.csv', index=False)

# %%
#                    HOST

# %%
b = pd.DataFrame(airbnb['host'])
b
# Out:
#                                                    host
# 0     {'host_id': '51399391', 'host_url': 'https://w...
# 1     {'host_id': '51530266', 'host_url': 'https://w...
# 2     {'host_id': '51670240', 'host_url': 'https://w...
# 3     {'host_id': '454250', 'host_url': 'https://www...
# 4     {'host_id': '1282196', 'host_url': 'https://ww...
# ...                                                 ...
# 5550  {'host_id': '19439282', 'host_url': 'https://w...
# 5551  {'host_id': '15831497', 'host_url': 'https://w...
# 5552  {'host_id': '8333722', 'host_url': 'https://ww...
# 5553  {'host_id': '2296185', 'host_url': 'https://ww...
# 5554  {'host_id': '51013381', 'host_url': 'https://w...
#
# [5555 rows x 1 columns]

# %%
host = pd.DataFrame(b)

# Extract 'host_id' and 'host_name' from 'host' dictionary
host['host_id'] = host['host'].apply(lambda x: x['host_id'])
host['host_url'] = host['host'].apply(lambda x: x['host_url'])
host['host_name'] = host['host'].apply(lambda x: x['host_name'])
host['host_location'] = host['host'].apply(lambda x: x['host_location'])
host['host_about'] = host['host'].apply(lambda x: x['host_about'])
host['host_response_time'] = host['host'].apply(lambda x: x.get('host_response_time','null'))
host['host_thumbnail_urlt'] = host['host'].apply(lambda x: x['host_thumbnail_url'])
host['host_picture_url'] = host['host'].apply(lambda x: x['host_picture_url'])
host['host_neighbourhood'] = host['host'].apply(lambda x: x['host_neighbourhood'])
host['host_response_rate'] = host['host'].apply(lambda x: x.get('host_response_rate',0))
host['host_is_superhost'] = host['host'].apply(lambda x: x['host_is_superhost'])
host['host_has_profile_pic'] = host['host'].apply(lambda x: x['host_has_profile_pic'])
host['host_identity_verified'] = host['host'].apply(lambda x: x['host_identity_verified'])
host['host_listings_count'] = host['host'].apply(lambda x: x['host_listings_count'])
host['host_total_listings_count'] = host['host'].apply(lambda x: x['host_total_listings_count'])
#host['host_verifications'] = host['host']['host_verifications'].apply(len)
host['host_verifications'] = host['host'].apply(lambda x: x['host_verifications'])
host['host_verifications'] = host['host_verifications'].apply(len)
# Drop the original 'host' column if not needed
host.drop(columns=['host'], inplace=True)

# Display the updated DataFrame
#print(host)

# %%
host[host['host_id'] == 53319251]
# Out:
# Empty DataFrame
# Columns: [host_id, host_url, host_name, host_location, host_about, host_response_time, host_thumbnail_urlt, host_picture_url, host_neighbourhood, host_response_rate, host_is_superhost, host_has_profile_pic, host_identity_verified, host_listings_count, host_total_listings_count, host_verifications]
# Index: []

# %%
print(host['host_response_time'].value_counts())
print(host['host_response_rate'].value_counts())
# Out:
# host_response_time
# within an hour        2715
# null                  1388
# within a few hours     742
# within a day           566
# a few days or more     144
# Name: count, dtype: int64
# host_response_rate
# 100    2952
# 0      1485
# 90      133
# 98      109
# 99      104
#        ...
# 17        1
# 42        1
# 30        1
# 59        1
# 84        1
# Name: count, Length: 62, dtype: int64

# %%
#host['host_response_time'] = host['host_response_time'].replace('null', 'other')

# Print the DataFrame to verify the changes
#print(host)

# %%
#host['host_response_rate'] = host['host_response_rate'].replace('0', '0')

# Print the DataFrame to verify the changes
#print(host)

# %%
#host.duplicated().sum()

# %%
host.drop_duplicates(inplace=True)

# %%
host.describe()
# Out:
#        host_response_rate  host_listings_count  host_total_listings_count  \
# count         5555.000000          5555.000000                5555.000000
# mean            69.851305            14.405761                  14.405761
# std             43.398098            65.848868                  65.848868
# min              0.000000             0.000000                   0.000000
# 25%              0.000000             1.000000                   1.000000
# 50%            100.000000             2.000000                   2.000000
# 75%            100.000000             6.000000                   6.000000
# max            100.000000          1198.000000                1198.000000
#
#        host_verifications
# count         5555.000000
# mean             4.968497
# std              2.176059
# min              1.000000
# 25%              3.000000
# 50%              5.000000
# 75%              7.000000
# max             12.000000

# %%
Q1 = host['host_response_rate'].quantile(0.25)
Q3 = host['host_response_rate'].quantile(0.75)
IQR = Q3 - Q1

# Define the lower and upper bounds for outlier detection
lower_bound = Q1 - (1.5 * IQR)
upper_bound = Q3 + (1.5 * IQR)


lower_bound ,upper_bound

#print(outliers)
# Out:
# (-150.0, 250.0)

# %%
host.host_response_rate = host.host_response_rate.clip(upper_bound , lower_bound )

# %%
Q1 = host['host_listings_count'].quantile(0.25)
Q3 = host['host_listings_count'].quantile(0.75)
IQR = Q3 - Q1

# Define the lower and upper bounds for outlier detection
lower_bound = Q1 - (1.5 * IQR)
upper_bound = Q3 + (1.5 * IQR)


lower_bound ,upper_bound

#print(outliers)
# Out:
# (-6.5, 13.5)

# %%
host.host_listings_count = host.host_listings_count.clip(upper_bound , lower_bound )

# %%
Q1 = host['host_total_listings_count'].quantile(0.25)
Q3 = host['host_total_listings_count'].quantile(0.75)
IQR = Q3 - Q1

# Define the lower and upper bounds for outlier detection
lower_bound = Q1 - (1.5 * IQR)
upper_bound = Q3 + (1.5 * IQR)


lower_bound ,upper_bound

#print(outliers)
# Out:
# (-6.5, 13.5)

# %%
host.host_total_listings_count = host.host_total_listings_count.clip(upper_bound , lower_bound )

# %%
Q1 = host['host_verifications'].quantile(0.25)
Q3 = host['host_verifications'].quantile(0.75)
IQR = Q3 - Q1

# Define the lower and upper bounds for outlier detection
lower_bound = Q1 - (1.5 * IQR)
upper_bound = Q3 + (1.5 * IQR)


lower_bound ,upper_bound

#print(outliers)
# Out:
# (-3.0, 13.0)

# %%
host.host_verifications = host.host_verifications.clip(upper_bound , lower_bound )

# %%
host = pd.DataFrame(host)
host
# Out:
#        host_id                                    host_url       host_name  \
# 0     51399391  https://www.airbnb.com/users/show/51399391     Ana&Gonçalo
# 1      1282196   https://www.airbnb.com/users/show/1282196           Ynaie
# 2      5448114   https://www.airbnb.com/users/show/5448114           David
# 3     11275734  https://www.airbnb.com/users/show/11275734            Josh
# 4     51496939  https://www.airbnb.com/users/show/51496939           Livia
# ...        ...                                         ...             ...
# 5550  37776205  https://www.airbnb.com/users/show/37776205             Ana
# 5551  51303748  https://www.airbnb.com/users/show/51303748            Eren
# 5552  51314789  https://www.airbnb.com/users/show/51314789          Dumont
# 5553  51013381  https://www.airbnb.com/users/show/51013381  Coconut Condos
# 5554  51013381  https://www.airbnb.com/users/show/51013381  Coconut Condos
#
#                                         host_location  \
# ...

# %%
host.to_csv('host_duplicates.csv', index=False)

# %%
df_1 = pd.read_csv('host_duplicates.csv')
df_1
# Out:
#        host_id                                    host_url       host_name  \
# 0     51399391  https://www.airbnb.com/users/show/51399391     Ana&Gonçalo
# 1     51530266  https://www.airbnb.com/users/show/51530266     Ana Valéria
# 2     51670240  https://www.airbnb.com/users/show/51670240        Jonathan
# 3       454250    https://www.airbnb.com/users/show/454250           Greta
# 4      1282196   https://www.airbnb.com/users/show/1282196           Ynaie
# ...        ...                                         ...             ...
# 5550  19439282  https://www.airbnb.com/users/show/19439282          Monika
# 5551  15831497  https://www.airbnb.com/users/show/15831497  Marcos Antonio
# 5552   8333722   https://www.airbnb.com/users/show/8333722            Leah
# 5553   2296185   https://www.airbnb.com/users/show/2296185          Manuel
# 5554  51013381  https://www.airbnb.com/users/show/51013381  Coconut Condos
#
#                                         host_location  \
# ...

# %%
df_1.drop(columns=['host_url'], inplace=True)
df_1.drop(columns=['host_about'], inplace=True)
df_1.drop(columns=['host_thumbnail_urlt'], inplace=True)
df_1.drop(columns=['host_picture_url'], inplace=True)
df_1.drop(columns=['host_picture_url'], inplace=True)
df_1.drop(columns=['host_neighbourhood'], inplace=True)

# %%
missing_values = df_1.isnull().sum()
#print("Missing Values:")
print(missing_values)
# Out:
# host_id                      0
# host_name                    0
# host_location                0
# host_response_time           0
# host_response_rate           0
# host_is_superhost            0
# host_has_profile_pic         0
# host_identity_verified       0
# host_listings_count          0
# host_total_listings_count    0
# host_verifications           0
# dtype: int64

# %%
duplicated_values = df_1.duplicated().sum()
#print("Missing Values:")
print(duplicated_values)
# Out:
# 451

# %%
#df_1['host_url'].fillna(df_1['host_url'].mean(), inplace=True)

# %%
df_1['host_location'].fillna('refer_address_table' ,inplace=True)

# %%
df_1['host_response_time'].fillna('within an hour', inplace=True)

# %%
missing_values = df_1[df_1['host_location'].isna()]

#Display the row(s) with missing value(s) in the 'suburb' column
#print(missing_values)

# %%
df_1
# Out:
#        host_id       host_name  \
# 0     51399391     Ana&Gonçalo
# 1     51530266     Ana Valéria
# 2     51670240        Jonathan
# 3       454250           Greta
# 4      1282196           Ynaie
# ...        ...             ...
# 5550  19439282          Monika
# 5551  15831497  Marcos Antonio
# 5552   8333722            Leah
# 5553   2296185          Manuel
# 5554  51013381  Coconut Condos
#
#                                         host_location  host_response_time  \
# 0                     Porto, Porto District, Portugal      within an hour
# 1     Rio de Janeiro, State of Rio de Janeiro, Brazil      within an hour
# 2                     Resende, Rio de Janeiro, Brazil      within an hour
# 3                   New York, New York, United States      within an hour
# 4     Rio de Janeiro, State of Rio de Janeiro, Brazil      within an hour
# ...                                               ...                 ...
# ...

# %%
df_1.to_csv('host_main.csv', index=False)

# %%
# aminities

# %%
c = pd.DataFrame(airbnb['amenities'])
c
# Out:
#                                               amenities
# 0     [TV, Cable TV, Wifi, Kitchen, Paid parking off...
# 1     [TV, Cable TV, Internet, Wifi, Air conditionin...
# 2     [TV, Cable TV, Internet, Wifi, Air conditionin...
# 3     [Internet, Wifi, Air conditioning, Kitchen, El...
# 4     [Wifi, Wheelchair accessible, Kitchen, Free pa...
# ...                                                 ...
# 5550  [TV, Cable TV, Internet, Wifi, Kitchen, Paid p...
# 5551  [TV, Cable TV, Internet, Wifi, Air conditionin...
# 5552  [TV, Wifi, Kitchen, Buzzer/wireless intercom, ...
# 5553  [TV, Cable TV, Wifi, Kitchen, Elevator, Heatin...
# 5554  [TV, Cable TV, Wifi, Air conditioning, Wheelch...
#
# [5555 rows x 1 columns]

# %%
len(c['amenities'][2])
# Out:
# 36

# %%
for column in c['amenities']:
    column_length = len(column)
    #print(column_length)

# %%
amenities = pd.DataFrame(c)

# Calculate lengths of each 'amenities' list and create a new column
amenities['amenities_length'] = amenities['amenities'].apply(len)

# Print the DataFrame
#print(amenities)
amenities = amenities.drop(columns=['amenities'])
amenities= pd.DataFrame(amenities)
amenities
# Out:
#       amenities_length
# 0                   32
# 1                   31
# 2                   17
# 3                   11
# 4                   15
# ...                ...
# 5550                24
# 5551                21
# 5552                 7
# 5553                15
# 5554                16
#
# [5555 rows x 1 columns]

# %%
amenities.to_csv('amenities', index=False)

# %%
df_2 = pd.read_csv('amenities_dup')
df_2
# Out:
#                                               amenities  amenities_length
# 0     ['TV', 'Cable TV', 'Wifi', 'Kitchen', 'Paid pa...                32
# 1     ['TV', 'Cable TV', 'Internet', 'Wifi', 'Air co...                31
# 2     ['TV', 'Cable TV', 'Internet', 'Wifi', 'Air co...                17
# 3     ['Internet', 'Wifi', 'Air conditioning', 'Kitc...                11
# 4     ['Wifi', 'Wheelchair accessible', 'Kitchen', '...                15
# ...                                                 ...               ...
# 5550  ['TV', 'Cable TV', 'Internet', 'Wifi', 'Kitche...                24
# 5551  ['TV', 'Cable TV', 'Internet', 'Wifi', 'Air co...                21
# 5552  ['TV', 'Wifi', 'Kitchen', 'Buzzer/wireless int...                 7
# 5553  ['TV', 'Cable TV', 'Wifi', 'Kitchen', 'Elevato...                15
# 5554  ['TV', 'Cable TV', 'Wifi', 'Air conditioning',...                16
#
# [5555 rows x 2 columns]

# %%
amenities.isnull().sum()
# Out:
# amenities           0
# amenities_length    0
# dtype: int64

# %%
missing_values = df_2.isnull().sum()
#print("Missing Values:")
print(missing_values)
# Out:
# amenities           0
# amenities_length    0
# dtype: int64

# %%
amenities.describe()
# Out:
#        amenities_length
# count       5555.000000
# mean          21.854545
# std           11.400905
# min            1.000000
# 25%           13.000000
# 50%           20.000000
# 75%           28.000000
# max           76.000000

# %%
Q1 = amenities['amenities_length'].quantile(0.25)
Q3 = amenities['amenities_length'].quantile(0.75)
IQR = Q3 - Q1

# Define the lower and upper bounds for outlier detection
lower_bound = Q1 - (1.5 * IQR)
upper_bound = Q3 + (1.5 * IQR)


lower_bound ,upper_bound

#print(outliers)
# Out:
# (-9.5, 50.5)

# %%
amenities.amenities_length = amenities.amenities_length.clip(upper_bound , lower_bound )

# %%
amenities.duplicated().sum()
# Out:
# 5504

# %%
import pandas as pd

# Load your dataset into a pandas DataFrame
data_1 = c

# List of amenities you want to check for
amenities_to_check = ['TV', 'Wifi', 'Air conditioning', 'Parking', 'Pool', 'Gym','Cable TV','Kitchen','Paid parking off premises','Smoking allowed','Pets allowed','Buzzer/wireless intercom','Heating','Family/kid friendly',
 'Washer',
 'First aid kit',
 'Fire extinguisher',
 'Essentials',
 'Hangers',
 'Hair dryer',
 'Iron',
 'Pack ’n Play/travel crib',
 'Room-darkening shades',
 'Hot water',
 'Bed linens',
 'Extra pillows and blankets',
 'Microwave',
 'Coffee maker',
 'Refrigerator',
 'Dishwasher',
 'Dishes and silverware',
 'Cooking basics',
 'Oven',
 'Stove',
 'Cleaning before checkout',
 'Waterfront','Laptop friendly workspace','Essentials''Wheelchair accessible','Elevator','Hot tub','Microwave','BBQ grill',
 'Garden or backyard',
 'Well-lit path to entrance',
 'Disabled parking spot',
 'Step-free access',
 'Wide clearance to bed',
 'Step-free access']

# Check if 'amenities' column exists in the DataFrame
if 'amenities' in data_1.columns:
    # Create new columns for each amenity and encode them as True or False
    for amenity in amenities_to_check:
        data_1[amenity] = data_1['amenities'].apply(lambda x: amenity in x)
    
    # Drop the original 'amenities' column
    data_1.drop(columns=['amenities'], inplace=True)
else:
    print("The 'amenities' column does not exist in the dataset.")

# Print the updated DataFrame
#print(data_1)

# %%
amenities_1 = pd.DataFrame(data_1)
amenities_1
# Out:
#          TV  Wifi  Air conditioning  Parking   Pool    Gym  Cable TV  Kitchen  \
# 0      True  True             False    False  False  False      True     True
# 1     False  True             False    False  False  False     False     True
# 2      True  True              True    False   True  False      True     True
# 3     False  True              True    False  False  False     False     True
# 4      True  True              True    False   True   True      True     True
# ...     ...   ...               ...      ...    ...    ...       ...      ...
# 5550   True  True             False    False  False  False      True     True
# 5551   True  True             False    False  False  False      True     True
# 5552   True  True              True    False   True   True      True    False
# 5553   True  True              True    False   True  False      True     True
# 5554   True  True              True    False   True   True     False     True
#
# ...

# %%
d = pd.DataFrame(airbnb['images'])
d
# Out:
#                                                  images
# 0     {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 1     {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 2     {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 3     {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 4     {'thumbnail_url': '', 'medium_url': '', 'pictu...
# ...                                                 ...
# 5550  {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 5551  {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 5552  {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 5553  {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 5554  {'thumbnail_url': '', 'medium_url': '', 'pictu...
#
# [5555 rows x 1 columns]

# %%
d['images'][0]
# Out:
# {'thumbnail_url': '',
#  'medium_url': '',
#  'picture_url': 'https://a0.muscache.com/im/pictures/e83e702f-ef49-40fb-8fa0-6512d7e26e9b.jpg?aki_policy=large',
#  'xl_picture_url': ''}

# %%
images = pd.DataFrame(d)

# Extract image URLs from nested 'images' dictionary
#images['thumbnail_url'] = images['images'].apply(lambda x: x['thumbnail_url'])
#images['medium_url'] = images['images'].apply(lambda x: x['medium_url'])
images['picture_url'] = images['images'].apply(lambda x: x['picture_url'])
#images['xl_picture_url'] = images['images'].apply(lambda x: x['xl_picture_url'])

# Drop the original 'images' column if not needed
images.drop(columns=['images'], inplace=True)

# Display the updated DataFrame
#print(images)

# %%
images.isnull().sum()
# Out:
# picture_url    0
# dtype: int64

# %%
images.duplicated().sum()
# Out:
# 2

# %%
images.drop_duplicates(subset='picture_url', inplace=True)

# %%
images.duplicated().sum()
# Out:
# 0

# %%
images=pd.DataFrame(images)
images
# Out:
#                                             picture_url
# 0     https://a0.muscache.com/im/pictures/e83e702f-e...
# 1     https://a0.muscache.com/im/pictures/5b408b9e-4...
# 2     https://a0.muscache.com/im/pictures/15037101/5...
# 3     https://a0.muscache.com/im/pictures/72844c8c-f...
# 4     https://a0.muscache.com/im/pictures/59c516bd-c...
# ...                                                 ...
# 5550  https://a0.muscache.com/im/pictures/15b74c6a-8...
# 5551  https://a0.muscache.com/im/pictures/e40d18b2-1...
# 5552  https://a0.muscache.com/im/pictures/4a2a03e4-d...
# 5553  https://a0.muscache.com/im/pictures/7d08e433-5...
# 5554  https://a0.muscache.com/im/pictures/be1978c5-6...
#
# [5553 rows x 1 columns]

# %%
images.isnull()
# Out:
#       picture_url
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ...           ...
# 5550        False
# 5551        False
# 5552        False
# 5553        False
# 5554        False
#
# [5555 rows x 1 columns]

# %%
e =pd.DataFrame(airbnb['availability'])
e
# Out:
#                                            availability
# 0     {'availability_30': 28, 'availability_60': 47,...
# 1     {'availability_30': 7, 'availability_60': 19, ...
# 2     {'availability_30': 0, 'availability_60': 0, '...
# 3     {'availability_30': 0, 'availability_60': 0, '...
# 4     {'availability_30': 0, 'availability_60': 0, '...
# ...                                                 ...
# 5550  {'availability_30': 9, 'availability_60': 20, ...
# 5551  {'availability_30': 16, 'availability_60': 16,...
# 5552  {'availability_30': 0, 'availability_60': 0, '...
# 5553  {'availability_30': 28, 'availability_60': 54,...
# 5554  {'availability_30': 8, 'availability_60': 20, ...
#
# [5555 rows x 1 columns]

# %%
e['availability'][0]
# Out:
# {'availability_30': 28,
#  'availability_60': 47,
#  'availability_90': 74,
#  'availability_365': 239}

# %%
availability = pd.DataFrame(e)

availability['availability_30'] = availability['availability'].apply(lambda x: x['availability_30'])
availability['availability_60'] = availability['availability'].apply(lambda x: x['availability_60'])
availability['availability_90'] = availability['availability'].apply(lambda x: x['availability_90'])
availability['availability_365'] = availability['availability'].apply(lambda x: x['availability_365'])

availability.drop(columns=['availability'], inplace=True)

# %%
availability.isnull().sum()
# Out:
# availability_30     0
# availability_60     0
# availability_90     0
# availability_365    0
# dtype: int64

# %%
availability.duplicated().sum()
# Out:
# 2684

# %%
availability.describe()
# Out:
#        availability_30  availability_60  availability_90  availability_365
# count      5555.000000      5555.000000      5555.000000       5555.000000
# mean         11.816202        26.451305        42.758056        173.105671
# std          11.686113        23.476011        35.226897        139.841893
# min           0.000000         0.000000         0.000000          0.000000
# 25%           0.000000         0.000000         0.000000         17.000000
# 50%           8.000000        23.000000        43.000000        171.000000
# 75%          24.000000        52.000000        80.000000        317.000000
# max          30.000000        60.000000        90.000000        365.000000

# %%
Q1 = availability['availability_30'].quantile(0.25)
Q3 = availability['availability_30'].quantile(0.75)
IQR = Q3 - Q1

# Define the lower and upper bounds for outlier detection
lower_bound = Q1 - (1.5 * IQR)
upper_bound = Q3 + (1.5 * IQR)


lower_bound ,upper_bound


#print(outliers)
# Out:
# (-36.0, 60.0)

# %%
availability.availability_30 = availability.availability_30.clip(upper_bound , lower_bound )

# %%
Q1 = availability['availability_60'].quantile(0.25)
Q3 = availability['availability_60'].quantile(0.75)
IQR = Q3 - Q1

# Define the lower and upper bounds for outlier detection
lower_bound = Q1 - (1.5 * IQR)
upper_bound = Q3 + (1.5 * IQR)


lower_bound ,upper_bound


#print(outliers)
# Out:
# (-78.0, 130.0)

# %%
availability.availability_60 = availability.availability_60.clip(upper_bound , lower_bound )

# %%
Q1 = availability['availability_90'].quantile(0.25)
Q3 = availability['availability_90'].quantile(0.75)
IQR = Q3 - Q1

# Define the lower and upper bounds for outlier detection
lower_bound = Q1 - (1.5 * IQR)
upper_bound = Q3 + (1.5 * IQR)


lower_bound ,upper_bound


#print(outliers)
# Out:
# (-120.0, 200.0)

# %%
availability.availability_90 = availability.availability_90.clip(upper_bound , lower_bound )

# %%
Q1 = availability['availability_365'].quantile(0.25)
Q3 = availability['availability_365'].quantile(0.75)
IQR = Q3 - Q1

# Define the lower and upper bounds for outlier detection
lower_bound = Q1 - (1.5 * IQR)
upper_bound = Q3 + (1.5 * IQR)


lower_bound ,upper_bound


#print(outliers)
# Out:
# (-433.0, 767.0)

# %%
availability.availability_365 = availability.availability_365.clip(upper_bound , lower_bound )

# %%
availability = pd.DataFrame(availability)
availability
# Out:
#       availability_30  availability_60  availability_90  availability_365
# 0                  28               47               74               239
# 1                   7               19               33               118
# 2                   0                0                0                 0
# 3                   0                0                0                93
# 4                   0                0                0                 0
# ...               ...              ...              ...               ...
# 5550                9               20               20                20
# 5551               16               16               17               282
# 5552                0                0                0                 0
# 5553               28               54               82               351
# 5554                8               20               26               243
#
# [5555 rows x 4 columns]

# %%
availability.to_csv('availability_dup',index = False)

# %%
df_3 = pd.read_csv('availability_dup') 
df_3
# Out:
#       availability_30  availability_60  availability_90  availability_365
# 0                  28               47               74               239
# 1                   7               19               33               118
# 2                   0                0                0                 0
# 3                   0                0                0                93
# 4                   0                0                0                 0
# ...               ...              ...              ...               ...
# 5550                9               20               20                20
# 5551               16               16               17               282
# 5552                0                0                0                 0
# 5553               28               54               82               351
# 5554                8               20               26               243
#
# [5555 rows x 4 columns]

# %%
missing_values = df_3.isnull().sum()
#print("Missing Values:")
print(missing_values)
# Out:
# availability_30     0
# availability_60     0
# availability_90     0
# availability_365    0
# dtype: int64

# %%
df_3.to_csv('availability',index = False)

# %%
availability['availability_30'].duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4        True
#         ...
# 5550     True
# 5551     True
# 5552     True
# 5553     True
# 5554     True
# Name: availability_30, Length: 5555, dtype: bool

# %%
f = pd.DataFrame(airbnb['review_scores'])
f
# Out:
#                                           review_scores
# 0     {'review_scores_accuracy': 9, 'review_scores_c...
# 1     {'review_scores_accuracy': 10, 'review_scores_...
# 2                                                    {}
# 3     {'review_scores_accuracy': 10, 'review_scores_...
# 4                                                    {}
# ...                                                 ...
# 5550  {'review_scores_accuracy': 10, 'review_scores_...
# 5551  {'review_scores_accuracy': 9, 'review_scores_c...
# 5552                                                 {}
# 5553  {'review_scores_accuracy': 9, 'review_scores_c...
# 5554  {'review_scores_accuracy': 10, 'review_scores_...
#
# [5555 rows x 1 columns]

# %%
f['review_scores'][2]
# Out:
# {}

# %%
rating = pd.DataFrame(f)

# Extract review scores from nested 'review_scores' dictionary
rating['review_scores_accuracy'] = rating['review_scores'].apply(lambda x: x.get('review_scores_accuracy',0))
rating['review_scores_cleanliness'] = rating['review_scores'].apply(lambda x: x.get('review_scores_cleanliness',0))
rating['review_scores_checkin'] = rating['review_scores'].apply(lambda x: x.get('review_scores_checkin',0))
rating['review_scores_communication'] = rating['review_scores'].apply(lambda x: x.get('review_scores_communication',0))
rating['review_scores_location'] = rating['review_scores'].apply(lambda x: x.get('review_scores_location',0))
rating['review_scores_value'] = rating['review_scores'].apply(lambda x: x.get('review_scores_value',0))
rating['review_scores_rating'] = rating['review_scores'].apply(lambda x: x.get('review_scores_rating',0))

# Drop the original 'review_scores' column if not needed
rating.drop(columns=['review_scores'], inplace=True)

# Display the updated DataFrame
#print(rating)

# %%
rating.to_csv('rating_dup', index = False)

# %%
df_4 = pd.read_csv("rating_dup")
df_4
# Out:
#       review_scores_accuracy  review_scores_cleanliness  \
# 0                          9                          9
# 1                         10                         10
# 2                          0                          0
# 3                         10                          9
# 4                          0                          0
# ...                      ...                        ...
# 5550                      10                          9
# 5551                       9                          6
# 5552                       0                          0
# 5553                       9                          9
# 5554                      10                         10
#
#       review_scores_checkin  review_scores_communication  \
# 0                        10                           10
# 1                        10                           10
# 2                         0                            0
# 3                        10                           10
# ...

# %%
df_4 = pd.DataFrame(df_4)

# Replace 0 values with mean value for each column
for column in df_4.columns:
    mean_value = df_4[column].mean()
    df_4[column].replace(0, mean_value, inplace=True)

# %%
df_4
# Out:
#       review_scores_accuracy  review_scores_cleanliness  \
# 0                   9.000000                   9.000000
# 1                  10.000000                  10.000000
# 2                   7.018002                   6.845185
# 3                  10.000000                   9.000000
# 4                   7.018002                   6.845185
# ...                      ...                        ...
# 5550               10.000000                   9.000000
# 5551                9.000000                   6.000000
# 5552                7.018002                   6.845185
# 5553                9.000000                   9.000000
# 5554               10.000000                  10.000000
#
#       review_scores_checkin  review_scores_communication  \
# 0                 10.000000                    10.000000
# 1                 10.000000                    10.000000
# 2                  7.123852                     7.117552
# 3                 10.000000                    10.000000
# ...

# %%
df_4.to_csv('rating', index = False)

# %%
rating = pd.DataFrame(rating)
rating
# Out:
#       review_scores_accuracy  review_scores_cleanliness  \
# 0                          9                          9
# 1                         10                         10
# 2                          0                          0
# 3                         10                          9
# 4                          0                          0
# ...                      ...                        ...
# 5550                      10                          9
# 5551                       9                          6
# 5552                       0                          0
# 5553                       9                          9
# 5554                      10                         10
#
#       review_scores_checkin  review_scores_communication  \
# 0                        10                           10
# 1                        10                           10
# 2                         0                            0
# 3                        10                           10
# ...

# %%
rating.isnull().sum()
# Out:
# review_scores_accuracy         0
# review_scores_cleanliness      0
# review_scores_checkin          0
# review_scores_communication    0
# review_scores_location         0
# review_scores_value            0
# review_scores_rating           0
# dtype: int64

# %%
rating.duplicated().sum()
# Out:
# 4391

# %%
g = pd.DataFrame(airbnb['reviews'])
g
# Out:
#                                                 reviews
# 0     [{'_id': '58663741', 'date': 2016-01-03 05:00:...
# 1     [{'_id': '60037020', 'date': 2016-01-18 05:00:...
# 2                                                    []
# 3     [{'_id': '4351675', 'date': 2013-04-29 04:00:0...
# 4                                                    []
# ...                                                 ...
# 5550  [{'_id': '63295758', 'date': 2016-02-21 05:00:...
# 5551  [{'_id': '58652157', 'date': 2016-01-03 05:00:...
# 5552                                                 []
# 5553  [{'_id': '73527641', 'date': 2016-05-08 04:00:...
# 5554  [{'_id': '43174613', 'date': 2015-08-17 04:00:...
#
# [5555 rows x 1 columns]

# %%
airbnb['weekly_price'].isna().sum()
# Out:
# 4841

# %%
airbnb['weekly_price'].duplicated().sum()
# Out:
# 5231

# %%
print(airbnb['weekly_price'].isna().sum())
print(airbnb['weekly_price'].duplicated().sum())
# Out:
# 4841
# 5231

# %%
print(airbnb['reviews_per_month'].isna().sum())
print(airbnb['reviews_per_month'].duplicated().sum())
# Out:
# 5461
# 5546

# %%
print(airbnb['_id'].isna().sum())
print(airbnb['_id'].duplicated().sum())
# Out:
# 0
# 0

# %%
print(airbnb['listing_url'].isna().sum())
print(airbnb['listing_url'].duplicated().sum())
# Out:
# 0
# 0

# %%
print(airbnb['name'].isna().sum())
print(airbnb['name'].duplicated().sum())
# Out:
# 0
# 17

# %%
print(airbnb['summary'].isna().sum())
print(airbnb['summary'].duplicated().sum())
# Out:
# 0
# 295

# %%
print(airbnb['space'].isna().sum())
print(airbnb['space'].duplicated().sum())
# Out:
# 0
# 1667

# %%
print(airbnb['description'].isna().sum())
print(airbnb['description'].duplicated().sum())
# Out:
# 0
# 113

# %%
print(airbnb['neighborhood_overview'].isna().sum())
print(airbnb['neighborhood_overview'].duplicated().sum())
# Out:
# 0
# 2327

# %%
print(airbnb['notes'].isna().sum())
print(airbnb['notes'].duplicated().sum())
# Out:
# 0
# 3173

# %%
print(airbnb['transit'].isna().sum())
print(airbnb['transit'].duplicated().sum())
# Out:
# 0
# 2324

# %%
print(airbnb['access'].isna().sum())
print(airbnb['access'].duplicated().sum())
# Out:
# 0
# 2566

# %%
print(airbnb['interaction'].isna().sum())
print(airbnb['interaction'].duplicated().sum())
# Out:
# 0
# 2638

# %%
print(airbnb['house_rules'].isna().sum())
print(airbnb['house_rules'].duplicated().sum())
# Out:
# 0
# 2442

# %%
print(airbnb['property_type'].isna().sum())
print(airbnb['property_type'].duplicated().sum())
# Out:
# 0
# 5519

# %%
print(airbnb['room_type'].isna().sum())
print(airbnb['room_type'].duplicated().sum())
# Out:
# 0
# 5552

# %%
print(airbnb['bed_type'].isna().sum())
print(airbnb['bed_type'].duplicated().sum())
# Out:
# 0
# 5550

# %%
print(airbnb['minimum_nights'].isna().sum())
print(airbnb['minimum_nights'].duplicated().sum())
# Out:
# 0
# 5510

# %%
print(airbnb['maximum_nights'].isna().sum())
print(airbnb['maximum_nights'].duplicated().sum())
# Out:
# 0
# 5415

# %%
print(airbnb['maximum_nights'].isna().sum())
print(airbnb['maximum_nights'].duplicated().sum())
# Out:
# 0
# 5415

# %%
print(airbnb['cancellation_policy'].isna().sum())
print(airbnb['cancellation_policy'].duplicated().sum())
# Out:
# 0
# 5550

# %%
print(airbnb['last_scraped'].isna().sum())
print(airbnb['last_scraped'].duplicated().sum())
# Out:
# 0
# 5548

# %%
print(airbnb['calendar_last_scraped'].isna().sum())
print(airbnb['calendar_last_scraped'].duplicated().sum())
# Out:
# 0
# 5548

# %%
print(airbnb['first_review'].isna().sum())
print(airbnb['first_review'].duplicated().sum())
# Out:
# 1388
# 3868

# %%
print(airbnb['last_review'].isna().sum())
print(airbnb['last_review'].duplicated().sum())
# Out:
# 1388
# 4745

# %%
print(airbnb['accommodates'].isna().sum())
print(airbnb['accommodates'].duplicated().sum())
# Out:
# 0
# 5539

# %%
print(airbnb['bedrooms'].isna().sum())
print(airbnb['bedrooms'].duplicated().sum())
# Out:
# 5
# 5541

# %%
print(airbnb['beds'].isna().sum())
print(airbnb['beds'].duplicated().sum())
# Out:
# 13
# 5535

# %%
print(airbnb['number_of_reviews'].isna().sum())
print(airbnb['number_of_reviews'].duplicated().sum())
# Out:
# 0
# 5296

# %%
print(airbnb['bathrooms'].isna().sum())
print(airbnb['bathrooms'].duplicated().sum())
# Out:
# 10
# 5537

# %%
print(airbnb['price'].isna().sum())
print(airbnb['price'].duplicated().sum())
# Out:
# 0
# 4906

# %%
print(airbnb['security_deposit'].isna().sum())
print(airbnb['security_deposit'].duplicated().sum())
# Out:
# 2084
# 5341

# %%
print(airbnb['cleaning_fee'].isna().sum())
print(airbnb['cleaning_fee'].duplicated().sum())
# Out:
# 1531
# 5263

# %%
print(airbnb['extra_people'].isna().sum())
print(airbnb['extra_people'].duplicated().sum())
# Out:
# 0
# 5417

# %%
print(airbnb['guests_included'].isna().sum())
print(airbnb['guests_included'].duplicated().sum())
# Out:
# 0
# 5541

# %%
print(airbnb['weekly_price'].isna().sum())
print(airbnb['weekly_price'].duplicated().sum())
# Out:
# 4841
# 5231

# %%
print(airbnb['monthly_price'].isna().sum())
print(airbnb['monthly_price'].duplicated().sum())
# Out:
# 4899
# 5245

# %%
print(airbnb['reviews_per_month'].isna().sum())
print(airbnb['reviews_per_month'].duplicated().sum())
# Out:
# 5461
# 5546

# %%
airbnb.drop(columns=['reviews_per_month'], inplace=True)

# %%
airbnb.drop(columns=['monthly_price'], inplace=True)

# %%
airbnb.drop(columns=['weekly_price'], inplace=True)

# %%
airbnb
# Out:
#            _id                            listing_url  \
# 0     10006546  https://www.airbnb.com/rooms/10006546
# 1     10009999  https://www.airbnb.com/rooms/10009999
# 2      1001265   https://www.airbnb.com/rooms/1001265
# 3     10021707  https://www.airbnb.com/rooms/10021707
# 4     10030955  https://www.airbnb.com/rooms/10030955
# ...        ...                                    ...
# 5550   9983221   https://www.airbnb.com/rooms/9983221
# 5551   9985696   https://www.airbnb.com/rooms/9985696
# 5552   9987200   https://www.airbnb.com/rooms/9987200
# 5553   9990304   https://www.airbnb.com/rooms/9990304
# 5554   9993190   https://www.airbnb.com/rooms/9993190
#
#                                                    name  \
# 0                               Ribeira Charming Duplex
# 1                          Horto flat with small garden
# 2                      Ocean View Waikiki Marina w/prkg
# 3                              Private Room in Bushwick
# ...

# %%
address
# Out:
#                                       street           suburb  \
# 0                     Porto, Porto, Portugal
# 1     Rio de Janeiro, Rio de Janeiro, Brazil  Jardim Botânico
# 2                Honolulu, HI, United States            Oʻahu
# 3                Brooklyn, NY, United States         Brooklyn
# 4     Rio de Janeiro, Rio de Janeiro, Brazil            Lagoa
# ...                                      ...              ...
# 5550                  Porto, Porto, Portugal
# 5551               Kadıköy, İstanbul, Turkey             Moda
# 5552  Rio de Janeiro, Rio de Janeiro, Brazil       Copacabana
# 5553              Lahaina, HI, United States             Maui
# 5554              Lahaina, HI, United States          Lahaina
#
#                                         government_area          market  \
# 0     Cedofeita, Ildefonso, Sé, Miragaia, Nicolau, V...           Porto
# 1                                       Jardim Botânico  Rio De Janeiro
# ...

# %%
host
# Out:
#        host_id                                    host_url       host_name  \
# 0     51399391  https://www.airbnb.com/users/show/51399391     Ana&Gonçalo
# 1      1282196   https://www.airbnb.com/users/show/1282196           Ynaie
# 2      5448114   https://www.airbnb.com/users/show/5448114           David
# 3     11275734  https://www.airbnb.com/users/show/11275734            Josh
# 4     51496939  https://www.airbnb.com/users/show/51496939           Livia
# ...        ...                                         ...             ...
# 5547   2068687   https://www.airbnb.com/users/show/2068687  Daniel & Maria
# 5548  51283546  https://www.airbnb.com/users/show/51283546          Alexis
# 5551  51303748  https://www.airbnb.com/users/show/51303748            Eren
# 5552  51314789  https://www.airbnb.com/users/show/51314789          Dumont
# 5553  51013381  https://www.airbnb.com/users/show/51013381  Coconut Condos
#
#                                         host_location  \
# ...

# %%
availability
# Out:
#       availability_30  availability_60  availability_90  availability_365
# 0                  28               47               74               239
# 1                   0                0                0                 0
# 2                  16               46               76               343
# 3                   0                0                0                 0
# 4                  28               58               88               363
# ...               ...              ...              ...               ...
# 5550               26               51               77               300
# 5551               30               60               90               365
# 5552                7               29               53                53
# 5553                8               20               26               243
# 5554                0                8               31               258
#
# [5555 rows x 4 columns]

# %%
rating
# Out:
#       review_scores_accuracy  review_scores_cleanliness  \
# 0                          9                          9
# 1                          0                          0
# 2                          9                          8
# 3                         10                         10
# 4                          0                          0
# ...                      ...                        ...
# 5550                      10                         10
# 5551                       0                          0
# 5552                      10                         10
# 5553                      10                         10
# 5554                      10                          9
#
#       review_scores_checkin  review_scores_communication  \
# 0                        10                           10
# 1                         0                            0
# 2                         9                            9
# 3                        10                           10
# ...

# %%
amenities
# Out:
#       amenities_length
# 0                   32
# 1                   15
# 2                   36
# 3                   10
# 4                   16
# ...                ...
# 5550                38
# 5551                15
# 5552                26
# 5553                16
# 5554                15
#
# [5555 rows x 1 columns]

# %%
images
# Out:
#                                             picture_url
# 0     https://a0.muscache.com/im/pictures/e83e702f-e...
# 1     https://a0.muscache.com/im/pictures/5b408b9e-4...
# 2     https://a0.muscache.com/im/pictures/15037101/5...
# 3     https://a0.muscache.com/im/pictures/72844c8c-f...
# 4     https://a0.muscache.com/im/pictures/59c516bd-c...
# ...                                                 ...
# 5550  https://a0.muscache.com/im/pictures/15b74c6a-8...
# 5551  https://a0.muscache.com/im/pictures/e40d18b2-1...
# 5552  https://a0.muscache.com/im/pictures/4a2a03e4-d...
# 5553  https://a0.muscache.com/im/pictures/7d08e433-5...
# 5554  https://a0.muscache.com/im/pictures/be1978c5-6...
#
# [5555 rows x 1 columns]
